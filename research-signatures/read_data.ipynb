# %%
import os

# %%
i = 0
a = 400
b = 450

for root,_,files in os.walk("GPDSS10000/"):
    if not 'overlap90p' in root:
        continue
    for f in files:
        i += 1
        if i < a:
            break
            
        fname = os.path.join(root, f)
        # %time fdata = pd.read_parquet(fname)
        print(fname, fdata.shape)
        print()
        break
    if i > b:
        raise IOError
# Out:
# CPU times: user 384 ms, sys: 62.7 ms, total: 447 ms
# Wall time: 162 ms
# GPDSS10000/3497/overlap90p/cf-3497-20_features.parquet.gz (5637, 1030)
#
# CPU times: user 415 ms, sys: 28.3 ms, total: 443 ms
# Wall time: 197 ms
# GPDSS10000/8223/overlap90p/cf-8223-02_features.parquet.gz (6807, 1030)
#
# CPU times: user 412 ms, sys: 64.8 ms, total: 477 ms
# Wall time: 185 ms
# GPDSS10000/6589/overlap90p/c-6589-16_features.parquet.gz (6542, 1030)
#
# CPU times: user 367 ms, sys: 21.7 ms, total: 388 ms
# Wall time: 171 ms
# GPDSS10000/1003/overlap90p/c-1003-20_features.parquet.gz (4647, 1030)
#
# CPU times: user 337 ms, sys: 46.2 ms, total: 384 ms
# Wall time: 159 ms
# GPDSS10000/2201/overlap90p/c-2201-12_features.parquet.gz (4320, 1030)
#
# CPU times: user 421 ms, sys: 77.3 ms, total: 499 ms
# Wall time: 208 ms
# GPDSS10000/1518/overlap90p/cf-1518-16_features.parquet.gz (6977, 1030)
#
# CPU times: user 400 ms, sys: 62.7 ms, total: 463 ms
# Wall time: 184 ms
# ...

# %%
fdata = "GPDSS10000/1011/overlap90p/cf-1011-05_features.parquet.gz"

# %%
import pandas as pd

# %%
pd.read_parquet(fdata).shape
# Out:
# (3808, 1030)
